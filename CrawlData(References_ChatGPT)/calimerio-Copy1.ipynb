page_url3 = 'https://www.google.com/search?q=calimero%20flower%20%E1%BA%A3nh&tbm=isch&hl=en&tbs=rimg:CaAFDxO9K5l1YWcuGRyIoQc1sgIMCgIIABAAOgQIABAAwAIA&rlz=1C1YTUH_viVN1045VN1045&sa=X&ved=0CBsQuIIBahcKEwi44ILrj_X-AhUAAAAAHQAAAAAQDw&biw=1126&bih=929'
page_url2 = 'https://www.google.com/search?q=calimero%20flower%20%E1%BA%A3nh&tbm=isch&hl=en&tbs=rimg:CT3ZCeDTeVtjYU2Yg8wPHuGbsgIMCgIIABAAOgQIABAAwAIA&rlz=1C1YTUH_viVN1045VN1045&sa=X&ved=0CBwQuIIBahcKEwio-cLmj_X-AhUAAAAAHQAAAAAQBw&biw=1126&bih=929'
page_url1 = 'https://www.google.com/search?q=calimero%20flower%20%E1%BA%A3nh&tbm=isch&hl=en&tbs=rimg:CV_1NCa2X0ELPYeukNLeww6ETsgIMCgIIABAAOgQIABAAwAIA&rlz=1C1YTUH_viVN1045VN1045&sa=X&ved=0CB4QuIIBahcKEwioz5XWjfX-AhUAAAAAHQAAAAAQBw&biw=1126&bih=929'
page_url = 'https://www.google.com/search?q=calimero%20flower%20%E1%BA%A3nh&tbm=isch&hl=en&tbs=rimg:CdlMXIvOGKpUYSaIl5MlDoMisgIMCgIIABAAOgQIABAAwAIA&rlz=1C1YTUH_viVN1045VN1045&sa=X&ved=0CBwQuIIBahcKEwjog7yIjPX-AhUAAAAAHQAAAAAQBw&biw=1126&bih=929'

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import StaleElementReferenceException
from bs4 import BeautifulSoup
import time
def get_unique_image_links(page_urls, exclude_list, max_links, desired_length):
    driver = webdriver.Chrome()
    unique_links = set()

    for page_url in page_urls:
        driver.get(page_url)
        while len(unique_links) < max_links:
            prev_height = driver.execute_script("return document.documentElement.scrollHeight")
            driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
            time.sleep(1) 
            try:
                images = driver.find_elements(By.TAG_NAME, 'img')
                image_links = []
                for image in images:
                    imgData = image.get_attribute('src')
                    if imgData and imgData.startswith('https'):
                        image_links.append(imgData)

                for imgData in image_links:
                    if imgData not in unique_links:
                        if not any(exclude_value in imgData for exclude_value in exclude_list):
                            if len(imgData) == desired_length:
                                unique_links.add(imgData)
                            if len(unique_links) == max_links:
                                break
            except StaleElementReferenceException:
                continue
            new_height = driver.execute_script("return document.documentElement.scrollHeight")
            if new_height == prev_height:
                break

    driver.quit()

    for link in unique_links:
        print(link)

    return unique_links

# %%
SS = [
    page_url10,
    page_url9,
    page_url8,
    page_url7,
    page_url6,
    page_url5,
    page_url4,
    page_url3,
    page_url2,
    page_url1
]
exclude_list = [] 
max_links = 500
IMG_LINKS3=get_unique_image_links(SS, exclude_list, max_links,99)
# Out:
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQBQbi86u4XAx2WiwKRqOVEza6kRkzSqa4lRw&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSKxfXMaWuQS7khJj2ir_avUX1w4ACGSRTMQw&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS0D3pX-TZY7DaU0DiCBbYq_smMItkq1meFtQ&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQLFVkYtEgj5j8uoOOGqwA4koRaSE7bmCuwzA&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR5bo5kGniU30egGtG25MQa2sYrQtppJk4LmQ&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQuaJaQLPOyiNK85oC-CESwVRgum6M7Nm8Rag&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTnWJMHPLFtmsG2syhLzkGDEoUrqkpzrKOdrg&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSOIgQo2Q-ozb8llq_QQJKksliUYkv-WCLWSQ&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcStB6bYTREjH7NcQy5SFrQlH0ALK7KP3w65MQ&usqp=CAU
# ...

# %%
len(IMG_LINKS3)
# Out:
# 459

# %%
import os
import requests

def save_links_to_directory(links, directory_path):
    if not os.path.exists(directory_path):
        os.makedirs(directory_path)

    count = 1
    for link in links:

        filename = f"calimerio{count}.jpg"
        count += 1

        save_path = os.path.join(directory_path, filename)

        response = requests.get(link)


        with open(save_path, 'wb') as f:
            f.write(response.content)

        print(f"Đã lưu: {save_path}")

# %%
directory_path = 'D:/New folder/calimerio'  
save_links_to_directory(IMG_LINKS3, directory_path)
# Out:
# Đã lưu: D:/New folder/calimerio\calimerio1.jpg
# Đã lưu: D:/New folder/calimerio\calimerio2.jpg
# Đã lưu: D:/New folder/calimerio\calimerio3.jpg
# Đã lưu: D:/New folder/calimerio\calimerio4.jpg
# Đã lưu: D:/New folder/calimerio\calimerio5.jpg
# Đã lưu: D:/New folder/calimerio\calimerio6.jpg
# Đã lưu: D:/New folder/calimerio\calimerio7.jpg
# Đã lưu: D:/New folder/calimerio\calimerio8.jpg
# Đã lưu: D:/New folder/calimerio\calimerio9.jpg
# Đã lưu: D:/New folder/calimerio\calimerio10.jpg
# Đã lưu: D:/New folder/calimerio\calimerio11.jpg
# Đã lưu: D:/New folder/calimerio\calimerio12.jpg
# Đã lưu: D:/New folder/calimerio\calimerio13.jpg
# Đã lưu: D:/New folder/calimerio\calimerio14.jpg
# Đã lưu: D:/New folder/calimerio\calimerio15.jpg
# Đã lưu: D:/New folder/calimerio\calimerio16.jpg
# Đã lưu: D:/New folder/calimerio\calimerio17.jpg
# Đã lưu: D:/New folder/calimerio\calimerio18.jpg
# Đã lưu: D:/New folder/calimerio\calimerio19.jpg
# Đã lưu: D:/New folder/calimerio\calimerio20.jpg
# ...
